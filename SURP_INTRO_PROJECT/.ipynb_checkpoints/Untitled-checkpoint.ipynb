# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
from myfunctions import PlottingLL,Plotting0

from lifelines import KaplanMeierFitter,NelsonAalenFitter


 

#****************DATA UPLOAD***************************************#
stime = np.load('stime_eb25_ap25_Mu0.20_Np30_logsp1.npy')
Ne, Na,Nmu,Np = 25,25,1,30 #Np = number of test particles per (eb,ap)tuple 
ab = 1
ebs = np.linspace(0.,0.7,Ne)
aps = ab*np.linspace(1.,5.,Na)
mus = np.array([0.20])



#Plotting0.Plotting0(ebs,aps,Ne,stime,Np)

fig,ax = plt.subplots(nrows =5, ncols = 5, figsize=(45,45))

#PlottingLL.PlottingLL(stime[1,2,0,:],ebs,aps,mus,Np)


for e,eb in enumerate(ebs[:5]):
    for a,ap in enumerate(aps[:5]):
        for m,mu in enumerate(mus):
            im = ax[e,a].imshow(PlottingLL.PlottingLL(eb,ap,mu,stime[e,a,m,:],Np), aspect='auto', origin="lower", interpolation='nearest', cmap="viridis")

            #ax[e,a].plot(PlottingLL.PlottingLL(eb,ap,mu,stime[e,a,m,:],Np))
            
            
            



            #***************EVENT OBSERVATION**********************************#

#             E = np.zeros(Np).astype(int)
#             for i,time in enumerate(stime[e,a,m,:]):
#                 if (time >= 62831):
#                     E[i] = 0
#                 else:
#                     E[i] = 1

#             #***************MAKING A DATA FRAME*********************************#
#             data1 = {'T':stime[e,a,m,:], 'E':E}
#             df = pd.DataFrame(data=data1)
#             #print(df.head())

#             T = df['T']
#             E = df['E']

#             #*********************KMF FITTING************************************#
#             kmf = KaplanMeierFitter()

#             kmf.fit(T,E)

#             fig,axs = plt.subplots(1,25)

#             kmf.survival_function_
#             #kmf.plot_survival_function()
#             kmf.survival_function_.plot(ax=axs[0])
         

#             #***********ESTIMATING HAZARD RATE USING NELSON_AALEN***************#
#             naf = NelsonAalenFitter()
#             naf.fit(T,E)
#             #print(naf.cumulative_hazard_.head())
#             #naf.plot_cumulative_hazard()
#             naf.cumulative_hazard_.plot(ax=axs[1])
#             plt.suptitle('For (eb,ap,mu) = {}'.format((eb,ap,mu)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-0b008cd86fe7> in <module>
#      29     for a,ap in enumerate(aps[:5]):
#      30         for m,mu in enumerate(mus):
# ---> 31             im = ax[e,a].imshow(PlottingLL.PlottingLL(eb,ap,mu,stime[e,a,m,:],Np), aspect='auto', origin="lower", interpolation='nearest', cmap="viridis")
#      32
#      33             #ax[e,a].plot(PlottingLL.PlottingLL(eb,ap,mu,stime[e,a,m,:],Np))
#
# /opt/python/3.8.2/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...
