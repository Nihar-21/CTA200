# %%
import numpy as np
from numpy import save
import rebound
import random
from multiprocessing import Pool
from myfunctions import SimulationLL as simL


def HW_crit(e,m):
    # eq 3. from H&W(1999)
    # e,m = eb, mu
    a_crit = 1.6 + 5.1*e - 2.22*e**2 + 4.12*m - 4.27*e*m - 5.09*m**2 + 4.61*e**2*m**2
    return a_crit


if __name__ == "__main__":
    random.seed(1)
    Na1, Na2 = 30, 10
    Ne, Na,Nmu,Np = 1,Na1+(Na2*2)-2,1,30 #Np = number of test particles per (eb,ap)tuple 
#     Ne,Na, Nmu, Np =  1,10,1,10
    #Na = 50
    ab = 1
    ebs = np.array([0])

#     ebs = np.linspace(0.,0.9,Ne) #changed from 0.7 to 0.9 (07/28/22)
    aps = ab*np.linspace(1.,5.,Na)
    mus = np.array([0.5])


 
    params = [(eb,ap,mu,Np) for eb in ebs for ap in aps for mu in mus]
#     print(params)
    
    pool = rebound.InterruptiblePool(processes = 16) #add number of processors same as number requested on Sunnyvale  

    import time
    import itertools
    start = time.time()
    num = 1
    for _ in itertools.repeat(None,num):
        stime = pool.map(simL.SimulationLL,params) #survival times
    end = time.time()
    print("Time elapsed in minutes is {}".format((end-start)/60.0))
    
    
    stime = np.array(stime).reshape([Ne,Na,Nmu,Np])
    stime = np.nan_to_num(stime)
    
    print(stime)
    print(stime.shape)
# Out:
# SimSimSimSimSimSimSim
# SimSimSim
#
#
#
# (0, 1.0, 0.5, 2)
#
#
#
# (0, 2.333333333333333, 0.5, 2)
# (0, 2.7777777777777777, 0.5, 2)(0, 1.4444444444444444, 0.5, 2)
# (0, 1.8888888888888888, 0.5, 2)(0, 3.2222222222222223, 0.5, 2)(0, 3.6666666666666665, 0.5, 2)(0, 4.555555555555555, 0.5, 2)(0, 4.111111111111111, 0.5, 2)
#
# (0, 5.0, 0.5, 2)
#
#
# 0
#
#
#
#
# 0000001
# 00
#
# 0
#
#
#
# 1
#
# 11
# 111
# 11
#
# 1
#
#
# [0.00000000e+00 5.00050005e-02 1.00010001e-01 ... 1.99699700e+03
#  1.99849850e+03 2.00000000e+03]
#
#
#
# [0.00000000e+00 5.00050005e-02 1.00010001e-01 ... 1.99699700e+03
#  1.99849850e+03 2.00000000e+03][0.00000000e+00 5.00050005e-02 1.00010001e-01 ... 1.99699700e+03
#  1.99849850e+03 2.00000000e+03][0.00000000e+00 5.00050005e-02 1.00010001e-01 ... 1.99699700e+03
#  1.99849850e+03 2.00000000e+03]a = 1.0, e = 0, mu = 0.5: time = 0.0, 2 planets remaining
# [0.00000000e+00 5.00050005e-02 1.00010001e-01 ... 1.99699700e+03
#  1.99849850e+03 2.00000000e+03][0.00000000e+00 5.00050005e-02 1.00010001e-01 ... 1.99699700e+03
#  1.99849850e+03 2.00000000e+03]
# [0.00000000e+00 5.00050005e-02 1.00010001e-01 ... 1.99699700e+03
#  1.99849850e+03 2.00000000e+03]
#
# [0.00000000e+00 5.00050005e-02 1.00010001e-01 ... 1.99699700e+03
#  1.99849850e+03 2.00000000e+03]
#
# [0.00000000e+00 5.00050005e-02 1.00010001e-01 ... 1.99699700e+03
#  1.99849850e+03 2.00000000e+03][0.00000000e+00 5.00050005e-02 1.00010001e-01 ... 1.99699700e+03
#  1.99849850e+03 2.00000000e+03]
# a = 2.333333333333333, e = 0, mu = 0.5: time = 0.0, 2 planets remaining
# a = 1.4444444444444444, e = 0, mu = 0.5: time = 0.0, 2 planets remaininga = 2.7777777777777777, e = 0, mu = 0.5: time = 0.0, 2 planets remaining
#
# a = 1.8888888888888888, e = 0, mu = 0.5: time = 0.0, 2 planets remaining
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 0.0, 2 planets remainingplanet 3 ejected at time = 0.00833 mins, (r = 0.62656,e=0.99970)a = 4.555555555555555, e = 0, mu = 0.5: time = 0.0, 2 planets remaining
#
# a = 4.111111111111111, e = 0, mu = 0.5: time = 0.0, 2 planets remaining
# a = 5.0, e = 0, mu = 0.5: time = 0.0, 2 planets remaininga = 3.6666666666666665, e = 0, mu = 0.5: time = 0.0, 2 planets remaining
#
#
#
#
#
# {0} planets remaining 1
# 1 planets remaining
# planet 3 ejected at time = 0.02334 mins, (r = 0.98650,e=1.11018)
# planet 2 ejected at time = 0.01250 mins, (r = 0.54703,e=0.99731){0} planets remaining
#  {0} planets remaining1
# 0
# 1 planets remaining0 planets remaining
#
# simulation finished, 0 planets remainingplanet 2 ejected at time = 0.02417 mins, (r = 0.88504,e=1.05678)
#
# {0} planets remaining 0
# 0 planets remaining
# simulation finished, 0 planets remaining
# planet 2 ejected at time = 0.25836 mins, (r = 1.22927,e=1.01495)
# {0} planets remaining 1
# 1 planets remaining
# a = 1.8888888888888888, e = 0, mu = 0.5: time = 50.00500050005, 1 planets remaining
# a = 4.555555555555555, e = 0, mu = 0.5: time = 50.00500050005, 2 planets remaininga = 5.0, e = 0, mu = 0.5: time = 50.00500050005, 2 planets remaining
#
# a = 4.111111111111111, e = 0, mu = 0.5: time = 50.00500050005, 2 planets remaining
# a = 3.6666666666666665, e = 0, mu = 0.5: time = 50.00500050005, 2 planets remaining
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 50.00500050005, 2 planets remaining
# a = 2.7777777777777777, e = 0, mu = 0.5: time = 50.00500050005, 2 planets remaining
# a = 2.333333333333333, e = 0, mu = 0.5: time = 50.00500050005, 2 planets remaining
# a = 1.8888888888888888, e = 0, mu = 0.5: time = 100.0100010001, 1 planets remaining
# a = 4.555555555555555, e = 0, mu = 0.5: time = 100.0100010001, 2 planets remaininga = 5.0, e = 0, mu = 0.5: time = 100.0100010001, 2 planets remaining
#
# a = 4.111111111111111, e = 0, mu = 0.5: time = 100.0100010001, 2 planets remaininga = 3.6666666666666665, e = 0, mu = 0.5: time = 100.0100010001, 2 planets remaining
#
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 100.0100010001, 2 planets remaining
# planet 2 ejected at time = 2.29440 mins, (r = 1.46232,e=1.00504)a = 2.7777777777777777, e = 0, mu = 0.5: time = 100.0100010001, 2 planets remaining
#
# {0} planets remaining 0
# a = 2.333333333333333, e = 0, mu = 0.5: time = 100.0100010001, 2 planets remaining0 planets remaining
#
# simulation finished, 0 planets remaining
# a = 5.0, e = 0, mu = 0.5: time = 150.01500150015002, 2 planets remaining
# a = 4.555555555555555, e = 0, mu = 0.5: time = 150.01500150015002, 2 planets remaining
# a = 4.111111111111111, e = 0, mu = 0.5: time = 150.01500150015002, 2 planets remaining
# a = 3.6666666666666665, e = 0, mu = 0.5: time = 150.01500150015002, 2 planets remaining
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 150.01500150015002, 2 planets remaining
# a = 2.7777777777777777, e = 0, mu = 0.5: time = 150.01500150015002, 2 planets remaining
# a = 2.333333333333333, e = 0, mu = 0.5: time = 150.01500150015002, 2 planets remaining
# a = 5.0, e = 0, mu = 0.5: time = 200.0200020002, 2 planets remaining
# a = 4.555555555555555, e = 0, mu = 0.5: time = 200.0200020002, 2 planets remaining
# a = 4.111111111111111, e = 0, mu = 0.5: time = 200.0200020002, 2 planets remaininga = 3.6666666666666665, e = 0, mu = 0.5: time = 200.0200020002, 2 planets remaining
#
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 200.0200020002, 2 planets remaining
# a = 2.7777777777777777, e = 0, mu = 0.5: time = 200.0200020002, 2 planets remaining
# a = 2.333333333333333, e = 0, mu = 0.5: time = 200.0200020002, 2 planets remaining
# a = 5.0, e = 0, mu = 0.5: time = 250.02500250025003, 2 planets remaining
# a = 4.555555555555555, e = 0, mu = 0.5: time = 250.02500250025003, 2 planets remaining
# a = 3.6666666666666665, e = 0, mu = 0.5: time = 250.02500250025003, 2 planets remaining
# a = 4.111111111111111, e = 0, mu = 0.5: time = 250.02500250025003, 2 planets remaining
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 250.02500250025003, 2 planets remaining
# a = 2.7777777777777777, e = 0, mu = 0.5: time = 250.02500250025003, 2 planets remaining
# a = 2.333333333333333, e = 0, mu = 0.5: time = 250.02500250025003, 2 planets remaining
# a = 5.0, e = 0, mu = 0.5: time = 300.03000300030004, 2 planets remaining
# a = 4.555555555555555, e = 0, mu = 0.5: time = 300.03000300030004, 2 planets remaining
# a = 3.6666666666666665, e = 0, mu = 0.5: time = 300.03000300030004, 2 planets remaining
# a = 4.111111111111111, e = 0, mu = 0.5: time = 300.03000300030004, 2 planets remaining
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 300.03000300030004, 2 planets remaining
# a = 2.7777777777777777, e = 0, mu = 0.5: time = 300.03000300030004, 2 planets remaining
# a = 2.333333333333333, e = 0, mu = 0.5: time = 300.03000300030004, 2 planets remaining
# a = 5.0, e = 0, mu = 0.5: time = 350.03500350035, 2 planets remaining
# a = 4.555555555555555, e = 0, mu = 0.5: time = 350.03500350035, 2 planets remaining
# a = 3.6666666666666665, e = 0, mu = 0.5: time = 350.03500350035, 2 planets remaining
# a = 4.111111111111111, e = 0, mu = 0.5: time = 350.03500350035, 2 planets remaining
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 350.03500350035, 2 planets remaining
# a = 2.7777777777777777, e = 0, mu = 0.5: time = 350.03500350035, 2 planets remaining
# a = 2.333333333333333, e = 0, mu = 0.5: time = 350.03500350035, 2 planets remaining
# a = 5.0, e = 0, mu = 0.5: time = 400.0400040004, 2 planets remaining
# a = 4.555555555555555, e = 0, mu = 0.5: time = 400.0400040004, 2 planets remaining
# a = 3.6666666666666665, e = 0, mu = 0.5: time = 400.0400040004, 2 planets remaining
# a = 4.111111111111111, e = 0, mu = 0.5: time = 400.0400040004, 2 planets remaining
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 400.0400040004, 2 planets remaining
# a = 2.7777777777777777, e = 0, mu = 0.5: time = 400.0400040004, 2 planets remaining
# a = 2.333333333333333, e = 0, mu = 0.5: time = 400.0400040004, 2 planets remaining
# a = 5.0, e = 0, mu = 0.5: time = 450.04500450045003, 2 planets remaining
# a = 4.555555555555555, e = 0, mu = 0.5: time = 450.04500450045003, 2 planets remaining
# a = 3.6666666666666665, e = 0, mu = 0.5: time = 450.04500450045003, 2 planets remaining
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 450.04500450045003, 2 planets remaining
# a = 4.111111111111111, e = 0, mu = 0.5: time = 450.04500450045003, 2 planets remaining
# a = 2.7777777777777777, e = 0, mu = 0.5: time = 450.04500450045003, 2 planets remaining
# a = 2.333333333333333, e = 0, mu = 0.5: time = 450.04500450045003, 2 planets remaining
# a = 5.0, e = 0, mu = 0.5: time = 501.5015015015015, 2 planets remaining
# a = 4.555555555555555, e = 0, mu = 0.5: time = 501.5015015015015, 2 planets remaining
# a = 3.6666666666666665, e = 0, mu = 0.5: time = 501.5015015015015, 2 planets remaining
# a = 3.2222222222222223, e = 0, mu = 0.5: time = 501.5015015015015, 2 planets remaining
# a = 4.111111111111111, e = 0, mu = 0.5: time = 501.5015015015015, 2 planets remaining
# a = 2.7777777777777777, e = 0, mu = 0.5: time = 501.5015015015015, 2 planets remaining
# a = 2.333333333333333, e = 0, mu = 0.5: time = 501.5015015015015, 2 planets remaining
# simulation finished, 2 planets remaining
# simulation finished, 2 planets remainingsimulation finished, 2 planets remaining
#
# simulation finished, 2 planets remaining
# simulation finished, 2 planets remaining
# simulation finished, 2 planets remaining
# simulation finished, 2 planets remaining
# Time elapsed in minutes is 0.04004858334859212
# [[[[7.50075008e-01 5.00050005e-01]]
#
#   [[1.45014501e+00 1.40014001e+00]]
#
#   [[1.37663766e+02 1.37663766e+02]]
#
#   [[2.00000000e+03 2.00000000e+03]]
#
#   [[2.00000000e+03 2.00000000e+03]]
#
#   [[2.00000000e+03 2.00000000e+03]]
#
#   [[2.00000000e+03 2.00000000e+03]]
#
#   [[2.00000000e+03 2.00000000e+03]]
#
#   [[2.00000000e+03 2.00000000e+03]]
#
#   [[2.00000000e+03 2.00000000e+03]]]]
# (1, 10, 1, 2)
