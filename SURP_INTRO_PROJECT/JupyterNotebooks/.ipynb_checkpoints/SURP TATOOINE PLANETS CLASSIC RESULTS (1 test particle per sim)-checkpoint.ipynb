# %%
import numpy as np
from numpy import save
import rebound
import random
from multiprocessing import Pool 

#Rebound Orbital Elements

# %%
def Simulation(par):
    sim = rebound.Simulation()

    e_b,a_p = par[0],par[1] 
    a_b = 1.
    m1 =1.
   
    sim.add(m=m1, hash = "Star1") 
    
    mu = 0.5
    m2 = (m1*mu)/(1-mu)
    f_b=np.random.rand()*2.*np.pi
    sim.add(m =m2, a= a_b, e=e_b,f=f_b,  hash = "Star2")
    
    e_p = 0
    f_p=np.random.rand()*2.*np.pi
    sim.add(m=0.,a=a_p,e=e_p,f=f_p, hash = "Planet1")
    
    sim.move_to_com()
    sim.automateSimulationArchive("archive_eb{:.3f}_ap{:.3f}.bin".format(e_b,a_p),interval = 1e3, deletefile = True)
    max_dist = 1000*a_b

    Torb = 2.*np.pi
    Noutputs = 100
    Norb_max = 1e4 
    Tmin = 0.
    Tmax = Norb_max*Torb
    times = np.linspace(Tmin, Tmax, Noutputs)
   
    tmax_arr = []
    for i,time in enumerate(times):
        sim.integrate(time)
        p = sim.particles[2]
        d2 = p.x**2 + p.y**2 + p.z**2
        tmax_arr.append(time)
        if(d2>max_dist**2):
            break  

# CHECKING SIMULATION ARCHIVE RETREIVAL
#     sa = rebound.SimulationArchive("archive_eb{:.3f}_ap{:.3f}.bin".format(e_b,a_p)) 
#     print("Number of snapshots: %d" % len(sa))
#     print("Time of first and last snap shots are: %.1f, %.1f" % (sa.tmin, sa.tmax))
#     sim = sa[1]
#     print(sim.t, sim.particles[2])



#     print("Survival time ",tmax_arr[-1])
    
    return tmax_arr[-1] #tmax

# %%
random.seed(1)
N = 4
ab = 1
ebs = np.linspace(0.,0.7,N)
aps = ab*np.linspace(1.,5.,N)

params = [(eb,ap) for eb in ebs for ap in aps]
print(params[0:0])


pool = rebound.InterruptiblePool()

# TO TIME ONE CALL TO THE METHOD
import time
import itertools
start = time.time()
num = 1
for _ in itertools.repeat(None,num):
   stime = pool.map(Simulation,params) #survival times
end = time.time()
print("Time elapsed is",end-start)

#stime = pool.map(Simulation,params) #survival times

stime = np.array(stime).reshape(N,N)
stime = np.nan_to_num(stime)
stime = stime.T
#save('stime1.npy', stime)
#Times = np.load('stime1.npy')
#print(Times)


# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib.colors import LogNorm
import matplotlib

t,ax = plt.subplots(1,1,figsize=(7,5))
extent=[ebs.min(), ebs.max(), aps.min(), aps.max()]

ax.set_xlim(extent[0], extent[1])
ax.set_ylim(extent[2], extent[3])
ax.set_xlabel("Binary Eccentricity $e_b$ ")
ax.set_ylabel("Test particle semimajor axis $a_p$")
im = ax.imshow(stime, aspect='auto', origin="lower", interpolation='nearest', cmap="viridis",extent=extent)


ebs = np.linspace(0.,0.7,N)
ab_s = np.zeros(N)
for i,eb in enumerate(ebs):
    ab_s[i] = 2.278 + 3.824*eb - 1.71*(eb**2)
   
plt.plot(ebs,ab_s,'c', marker = "^",markersize = 7)
plt.xlabel('$e_b$')
plt.ylabel('$a_b(a_c$)')
plt.title('Critical semimajor axis $a_c$ as a function of eccentricity $e_b$')


cb = plt.colorbar(im, ax=ax)
cb.solids.set_rasterized(True)
cb.set_label("Particle Survival Times")

#leNgth = np.zeros(N**2)
for i,tupl in enumerate(params):
   eb,ap = tupl[0],tupl[1] 
   sa = rebound.SimulationArchive("archive_eb{:.3f}_ap{:.3f}.bin".format(eb,ap)) 
   print("Number of snapshots: %d" % len(sa))
   print("Time of first and last snap shots are: %.1f, %.1f" % (sa.tmin, sa.tmax))
   sim = sa[1]
   print(sim.t, sim.particles[2])


#plt.show()

#plt.savefig("Classic_results.pdf")
# Out:
# []
# Time elapsed is 46.57795310020447
# Number of snapshots: 2
# Time of first and last snap shots are: 0.0, 1000.1
# 1000.0937812936522 <rebound.particle.Particle object at 0x7f63b82a22f0, m=0.0 x=-372.8960305681915 y=195.7143323009669 z=0.0 vx=-0.6098565539026461 vy=0.31409233659386326 vz=0.0>
# Number of snapshots: 63
# Time of first and last snap shots are: 0.0, 62000.0
# 1000.001719049154 <rebound.particle.Particle object at 0x7f63b82a2378, m=0.0 x=1.9900705089947754 y=-0.8514244991082253 z=0.0 vx=0.3946745020009879 vy=0.8934857702166026 vz=0.0>
# Number of snapshots: 63
# Time of first and last snap shots are: 0.0, 62000.0
# 1000.1000910271769 <rebound.particle.Particle object at 0x7f63b82a2488, m=0.0 x=-1.9465071802480947 y=2.971827615656409 z=0.0 vx=-0.6395279349270562 vy=-0.4152193932146142 vz=0.0>
# Number of snapshots: 63
# Time of first and last snap shots are: 0.0, 62000.1
# 1000.0941579857569 <rebound.particle.Particle object at 0x7f63b82a2598, m=0.0 x=-1.3397225027977284 y=-4.765543002132959 z=0.0 vx=0.6164203885684244 vy=-0.1683831595050611 vz=0.0>
# Number of snapshots: 2
# Time of first and last snap shots are: 0.0, 1000.0
# 1000.0372436149411 <rebound.particle.Particle object at 0x7f63b85c8f28, m=0.0 x=291.63629039852725 y=-607.926755655981 z=0.0 vx=0.2881982722110137 vy=-0.592163043480692 vz=0.0>
# Number of snapshots: 2
# Time of first and last snap shots are: 0.0, 1000.0
# 1000.0359125801515 <rebound.particle.Particle object at 0x7f63b82a2378, m=0.0 x=-382.29691488347106 y=471.43114451609983 z=0.0 vx=-0.4212575740818471 vy=0.5120192370013112 vz=0.0>
# Number of snapshots: 63
# Time of first and last snap shots are: 0.0, 62000.0
# 1000.0365090501172 <rebound.particle.Particle object at 0x7f63b82a2268, m=0.0 x=-2.1441793415462724 y=2.81897296151642 z=0.0 vx=-0.605584610444937 vy=-0.46442568893399616 vz=0.0>
# Number of snapshots: 63
# Time of first and last snap shots are: 0.0, 62000.0
# 1000.0365090501172 <rebound.particle.Particle object at 0x7f63b82a2598, m=0.0 x=-1.7816935257113655 y=-4.632961429813098 z=0.0 vx=0.5970669217555616 vy=-0.22431534592723348 vz=0.0>
# Number of snapshots: 4
# Time of first and last snap shots are: 0.0, 3000.1
# 1000.0339243980242 <rebound.particle.Particle object at 0x7f63b82a21e0, m=0.0 x=76.51824798144425 y=-235.594879030232 z=0.0 vx=0.10915822546315258 vy=-0.3016032151988334 vz=0.0>
# Number of snapshots: 2
# Time of first and last snap shots are: 0.0, 1000.0
# 1000.0325454470448 <rebound.particle.Particle object at 0x7f63b82a2620, m=0.0 x=-645.9603409755588 y=-230.46390627610944 z=0.0 vx=-0.6459931138141957 vy=-0.23364440515178764 vz=0.0>
# Number of snapshots: 63
# Time of first and last snap shots are: 0.0, 62000.0
# 1000.0333706428231 <rebound.particle.Particle object at 0x7f63b82a2158, m=0.0 x=2.8502026105976372 y=-2.3776016530485644 z=0.0 vx=0.4670122107354732 vy=0.561681768618862 vz=0.0>
# Number of snapshots: 63
# Time of first and last snap shots are: 0.0, 62000.0
# 1000.0333706428231 <rebound.particle.Particle object at 0x7f63b82a2598, m=0.0 x=-4.643737980548285 y=-1.901845306076389 z=0.0 vx=0.23911802499321128 vy=-0.5876248250935022 vz=0.0>
# Number of snapshots: 2
# Time of first and last snap shots are: 0.0, 1000.0
# 1000.0124509812945 <rebound.particle.Particle object at 0x7f63b82a20d0, m=0.0 x=-876.381982477271 y=-310.58155144812645 z=0.0 vx=-0.8684608345647746 vy=-0.31002022437380183 vz=0.0>
# Number of snapshots: 4
# Time of first and last snap shots are: 0.0, 3000.0
# 1000.0142520788246 <rebound.particle.Particle object at 0x7f63b82a2620, m=0.0 x=-54.91553445894248 y=20.310102082973295 z=0.0 vx=-0.06280874454744227 vy=-0.02720042541813812 vz=0.0>
# Number of snapshots: 63
# Time of first and last snap shots are: 0.0, 62000.0
# 1000.0120124742876 <rebound.particle.Particle object at 0x7f63b82a2400, m=0.0 x=3.3646875031165617 y=-1.6262089301560811 z=0.0 vx=0.3454333559161009 vy=0.6546632627682903 vz=0.0>
# Number of snapshots: 63
# Time of first and last snap shots are: 0.0, 62000.0
# 1000.0120124742876 <rebound.particle.Particle object at 0x7f63b82a2598, m=0.0 x=-1.6206841955631368 y=4.729099115485173 z=0.0 vx=-0.5988474028172152 vy=-0.20647409485459162 vz=0.0>
