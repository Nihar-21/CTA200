# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from matplotlib import pyplot as plt
import autograd.numpy as np
from autograd.scipy.special import expit, logit
import pandas as pd
plt.style.use('bmh')
from lifelines.fitters import ParametricRegressionFitter
from lifelines.datasets import load_rossi

# %%
import numpy as np
import matplotlib.pyplot as plt 
import lifelines
from myfunctions import PlottingLL  
from myfunctions import CureModelLL
from myfunctions import SevenPlot


stime = np.load('stime_eb25_ap25_Mu0.50_Np30_logsp1.npy')
Ne, Na, Nm, Np = 25,25,1,30

#binary semi-major axis
ab = 1

#binary eccentricity
ebs = np.linspace(0.,0.7,Ne)
#print(ebs)

    
#test particle semi- major axis 
aps = ab*np.linspace(1.,5.,Na)


# for x in range(0,25,6):
#     print(ebs[x])
    
for y in range(0,19,3):
    print(aps[y])
    
#Binary reduced mass
mu = 0.500



# for y in range(0,19,1):
#     stimes.append(stime[0,y,:])
#     n = 30
    
#     app = [aps[y]]*n
#     ap_s.append(app)
    
# stimes = list(np.concatenate(stimes).flat)
# ap_s = list(np.concatenate(ap_s).flat)


for y in range(0,19,3):
    CureModelLL.CureModelLL(np.abs(ebs[0]),aps[y],mu,stime[0,y,:],Np)
# Out:
# 1.0
# 1.5
# 2.0
# 2.5
# 3.0
# 3.5
# 4.0
# /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:985: ApproximationWarning:
# The Hessian for CureFitter's fit was not invertible. We will instead approximate it using the pseudo-inverse.
#
# It's advisable to not trust the variances reported, and to be suspicious of the fitted parameters too. Perform plots of the cumulative hazard to help understand the latter's bias.
#
#   warnings.warn(warning_text, exceptions.ApproximationWarning)
# /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:985: ApproximationWarning:
# The Hessian for CureFitter's fit was not invertible. We will instead approximate it using the pseudo-inverse.
#
# It's advisable to not trust the variances reported, and to be suspicious of the fitted parameters too. Perform plots of the cumulative hazard to help understand the latter's bias.
#
#   warnings.warn(warning_text, exceptions.ApproximationWarning)
# /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:985: ApproximationWarning:
# The Hessian for CureFitter's fit was not invertible. We will instead approximate it using the pseudo-inverse.
#
# It's advisable to not trust the variances reported, and to be suspicious of the fitted parameters too. Perform plots of the cumulative hazard to help understand the latter's bias.
#
#   warnings.warn(warning_text, exceptions.ApproximationWarning)
# /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:985: ApproximationWarning:
# The Hessian for CureFitter's fit was not invertible. We will instead approximate it using the pseudo-inverse.
#
# It's advisable to not trust the variances reported, and to be suspicious of the fitted parameters too. Perform plots of the cumulative hazard to help understand the latter's bias.
#
#   warnings.warn(warning_text, exceptions.ApproximationWarning)

# %%
from autograd.scipy.special import expit



class CureModel(ParametricRegressionFitter):
    _scipy_fit_method = "SLSQP"
    _scipy_fit_options = {"ftol": 1e-10, "maxiter": 200}

    _fitted_parameter_names = ["lambda_", "beta_", "rho_"]

    def _cumulative_hazard(self, params, T, Xs):
#         print(type(Xs["beta_"]))
#         print((Xs["beta_"]))
#         print(type(params["beta_"]))
#         print(params["beta_"])

        c = expit(np.dot(Xs["beta_"], params["beta_"]))
        print(c)


#         print(Xs["lambda_"])
#         print(params["lambda_"])
        lambda_ = np.exp(np.dot(Xs["lambda_"], params["lambda_"]))
#         print(lambda_)

#         print(Xs["rho_"])
#         print(params["rho_"])
        rho_ = np.exp(np.dot(Xs["rho_"], params["rho_"]))
#         print(rho_)
        
        sf = np.exp(-(T / lambda_) ** rho_)
#         print(sf)
#         print(-np.log((1 - c) + c * sf))

        return -np.log((1 - c) + c * sf)


cm = CureModel(penalizer=0.0)

rossi = load_rossi()
print(rossi)

# print(rossi)
# print(rossi.columns.difference(['week','arrest']))

# events = rossi['arrest'].astype(bool)
# print(rossi.loc[events, '('lambda_', 'fin')'].var())
# print(rossi.loc[~events, '('lambda_', 'fin')'].var())


covariates = {"lambda_": rossi.columns.difference(['week', 'arrest']), "rho_": "1", "beta_": 'fin + 1'}

cm.fit(rossi, "week", event_col="arrest", regressors=covariates, show_progress = True, timeline=np.arange(250))
cm.print_summary(2)
# Out:
#      week  arrest  fin  age  race  wexp  mar  paro  prio
# 0      20       1    0   27     1     0    0     1     3
# 1      17       1    0   18     1     0    0     1     8
# 2      25       1    0   19     0     1    0     1    13
# 3      52       0    1   23     1     1    1     1     1
# 4      52       0    0   19     0     1    0     1     3
# ..    ...     ...  ...  ...   ...   ...  ...   ...   ...
# 427    52       0    1   31     0     1    0     1     3
# 428    52       0    0   20     1     0    0     1     1
# 429    52       0    1   20     1     1    1     1     1
# 430    52       0    0   29     1     1    0     1     3
# 431    52       0    1   24     1     1    0     1     1
#
# [432 rows x 9 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <module>
#      43 # print(rossi)
#      44 # print(rossi.columns.difference(['week','arrest']))
#      45
#      46 # events = rossi['arrest'].astype(bool)
#      47 # print(rossi.loc[events, '('lambda_', 'fin')'].var())
#      48 # print(rossi.loc[~events, '('lambda_', 'fin')'].var())
#      51 covariates = {"lambda_": rossi.columns.difference(['week', 'arrest']), "rho_": "1", "beta_": 'fin + 1'}
# ---> 53 cm.fit(rossi, "week", event_col="arrest", regressors=covariates, show_progress = True, timeline=np.arange(250))
#      54 cm.print_summary(2)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/utils/__init__.py:56, in CensoringType.right_censoring.<locals>.f(model, *args, **kwargs)
#      53 @wraps(function)
#      54 def f(model, *args, **kwargs):
#      55     cls.set_censoring_type(model, cls.RIGHT)
# ---> 56     return function(model, *args, **kwargs)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:1712, in ParametricRegressionFitter.fit(self, df, duration_col, event_col, regressors, show_progress, timeline, weights_col, robust, initial_point, entry_col)
#    1708 df = df.copy()
#    1710 self.durations = utils.pass_for_numeric_dtypes_or_raise_array(df.pop(duration_col)).astype(float)
# -> 1712 self._fit(
#    1713     self._log_likelihood_right_censoring,
#    1714     df,
#    1715     (self.durations.values, None),
#    1716     event_col=event_col,
#    1717     regressors=regressors,
#    1718     show_progress=show_progress,
#    1719     timeline=timeline,
#    1720     weights_col=weights_col,
#    1721     robust=robust,
#    1722     initial_point=initial_point,
#    1723     entry_col=entry_col,
#    1724 )
#    1726 return self
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:1799, in ParametricRegressionFitter._fit(self, log_likelihood_function, df, Ts, regressors, event_col, show_progress, timeline, weights_col, robust, initial_point, entry_col)
#    1796 _norm_std[_norm_std < 1e-8] = 1.0
#    1798 self._pre_fit_model(Ts, E, Xs)
# -> 1799 _params, self.log_likelihood_, self._hessian_ = self._fit_model(
#    1800     log_likelihood_function,
#    1801     Ts,
#    1802     utils.normalize(Xs, 0, _norm_std),
#    1803     E.values,
#    1804     weights.values,
#    1805     entries.values,
#    1806     show_progress=show_progress,
#    1807     user_supplied_initial_point=initial_point,
#    1808 )
#    1810 # assert the coefficients are aligned.
#    1811 # https://github.com/CamDavidsonPilon/lifelines/issues/931
#    1812 assert list(self.regressors.keys()) == list(self._norm_std.index.get_level_values(0).unique())
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:1905, in ParametricRegressionFitter._fit_model(self, likelihood, Ts, Xs, E, weights, entries, show_progress, user_supplied_initial_point)
#    1902 if _initial_point.shape[0] != Xs.columns.size:
#    1903     raise ValueError("initial_point is not the correct shape.")
# -> 1905 results = minimize(
#    1906     # using value_and_grad is much faster (takes advantage of shared computations) than splitting.
#    1907     value_and_grad(self._neg_likelihood_with_penalty_function),
#    1908     _initial_point,
#    1909     method=self._scipy_fit_method,
#    1910     jac=True,
#    1911     args=(Ts, E, weights, entries, utils.DataframeSlicer(Xs)),
#    1912     options={**{"disp": show_progress}, **self._scipy_fit_options},
#    1913     callback=self._scipy_fit_callback,
#    1914 )
#    1916 if results.fun < minimum_ll:
#    1917     minimum_ll, minimum_results = results.fun, results
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/scipy/optimize/_minimize.py:631, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     629     return _minimize_cobyla(fun, x0, args, constraints, **options)
#     630 elif meth == 'slsqp':
# --> 631     return _minimize_slsqp(fun, x0, args, jac, bounds,
#     632                            constraints, callback=callback, **options)
#     633 elif meth == 'trust-constr':
#     634     return _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     635                                         bounds, constraints,
#     636                                         callback=callback, **options)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/scipy/optimize/slsqp.py:375, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     372     xu[infbnd[:, 1]] = np.nan
#     374 # ScalarFunction provides function and gradient evaluation
# --> 375 sf = _prepare_scalar_function(func, x, jac=jac, args=args, epsilon=eps,
#     376                               finite_diff_rel_step=finite_diff_rel_step,
#     377                               bounds=new_bounds)
#     378 # gh11403 SLSQP sometimes exceeds bounds by 1 or 2 ULP, make sure this
#     379 # doesn't get sent to the func/grad evaluator.
#     380 wrapped_fun = _clip_x_for_func(sf.fun, new_bounds)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/scipy/optimize/optimize.py:261, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     257     bounds = (-np.inf, np.inf)
#     259 # ScalarFunction caches. Reuse of fun(x) during grad
#     260 # calculation reduces overall function evaluations.
# --> 261 sf = ScalarFunction(fun, x0, args, grad, hess,
#     262                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     264 return sf
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:140, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     137     self.f = fun_wrapped(self.x)
#     139 self._update_fun_impl = update_fun
# --> 140 self._update_fun()
#     142 # Gradient evaluation
#     143 if callable(grad):
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:233, in ScalarFunction._update_fun(self)
#     231 def _update_fun(self):
#     232     if not self.f_updated:
# --> 233         self._update_fun_impl()
#     234         self.f_updated = True
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.update_fun()
#     136 def update_fun():
# --> 137     self.f = fun_wrapped(self.x)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:134, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     130 self.nfev += 1
#     131 # Send a copy because the user may overwrite it.
#     132 # Overwriting results in undefined behaviour because
#     133 # fun(self.x) will change self.x, with the two no longer linked.
# --> 134 return fun(np.copy(x), *args)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/scipy/optimize/optimize.py:74, in MemoizeJac.__call__(self, x, *args)
#      72 def __call__(self, x, *args):
#      73     """ returns the the function value """
# ---> 74     self._compute_if_needed(x, *args)
#      75     return self._value
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/scipy/optimize/optimize.py:68, in MemoizeJac._compute_if_needed(self, x, *args)
#      66 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67     self.x = np.asarray(x).copy()
# ---> 68     fg = self.fun(x, *args)
#      69     self.jac = fg[1]
#      70     self._value = fg[0]
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/wrap_util.py:20, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f(*args, **kwargs)
#      18 else:
#      19     x = tuple(args[i] for i in argnum)
# ---> 20 return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/differential_operators.py:135, in value_and_grad(fun, x)
#     131 @unary_to_nary
#     132 def value_and_grad(fun, x):
#     133     """Returns a function that returns both value and gradient. Suitable for use
#     134     in scipy.optimize"""
# --> 135     vjp, ans = _make_vjp(fun, x)
#     136     if not vspace(ans).size == 1:
#     137         raise TypeError("value_and_grad only applies to real scalar-output "
#     138                         "functions. Try jacobian, elementwise_grad or "
#     139                         "holomorphic_grad.")
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/core.py:10, in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/tracer.py:10, in trace(start_node, fun, x)
#       8 with trace_stack.new_trace() as t:
#       9     start_box = new_box(x, t, start_node)
# ---> 10     end_box = fun(start_box)
#      11     if isbox(end_box) and end_box._trace == start_box._trace:
#      12         return end_box._value, end_box._node
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/wrap_util.py:15, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f.<locals>.unary_f(x)
#      13 else:
#      14     subargs = subvals(args, zip(argnum, x))
# ---> 15 return fun(*subargs, **kwargs)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:1869, in ParametricRegressionFitter._create_neg_likelihood_with_penalty_function(self, params_array, Ts, E, weights, entries, Xs, likelihood, penalty)
#    1867     return -likelihood(params_dict, Ts, E, weights, entries, Xs)
#    1868 else:
# -> 1869     return penalty(params_dict, -likelihood(params_dict, Ts, E, weights, entries, Xs))
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:1393, in ParametricRegressionFitter._log_likelihood_right_censoring(self, params, Ts, E, W, entries, Xs)
#    1390 T = Ts[0]
#    1391 non_zero_entries = entries > 0
# -> 1393 log_hz = self._log_hazard(params, T, Xs)
#    1394 cum_hz = self._cumulative_hazard(params, T, Xs)
#    1395 delayed_entries = self._cumulative_hazard(params, entries[non_zero_entries], Xs.filter(non_zero_entries))
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:1377, in ParametricRegressionFitter._log_hazard(self, params, T, Xs)
#    1375 def _log_hazard(self, params, T, Xs):
#    1376     # can be overwritten to improve convergence, see example in WeibullAFTFitter
# -> 1377     hz = self._hazard(params, T, Xs)
#    1378     hz = anp.clip(hz, 1e-20, np.inf)
#    1379     return anp.log(hz)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/lifelines/fitters/__init__.py:1373, in ParametricRegressionFitter._hazard(self, params, T, Xs)
#    1372 def _hazard(self, params, T, Xs):
# -> 1373     return egrad(self._cumulative_hazard, argnum=1)(params, T, Xs)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/wrap_util.py:20, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f(*args, **kwargs)
#      18 else:
#      19     x = tuple(args[i] for i in argnum)
# ---> 20 return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/differential_operators.py:38, in elementwise_grad(fun, x)
#      31 @unary_to_nary
#      32 def elementwise_grad(fun, x):
#      33     """
#      34     Returns a function that computes the sum of each column of the Jacobian of
#      35     `fun`, in one pass. If the Jacobian is diagonal, then this is the diagonal
#      36     of the Jacobian.
#      37     """
# ---> 38     vjp, ans = _make_vjp(fun, x)
#      39     if vspace(ans).iscomplex:
#      40         raise TypeError("Elementwise_grad only applies to real-output functions.")
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/core.py:10, in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/tracer.py:10, in trace(start_node, fun, x)
#       8 with trace_stack.new_trace() as t:
#       9     start_box = new_box(x, t, start_node)
# ---> 10     end_box = fun(start_box)
#      11     if isbox(end_box) and end_box._trace == start_box._trace:
#      12         return end_box._value, end_box._node
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/wrap_util.py:15, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f.<locals>.unary_f(x)
#      13 else:
#      14     subargs = subvals(args, zip(argnum, x))
# ---> 15 return fun(*subargs, **kwargs)
#
# Input In [3], in CureModel._cumulative_hazard(self, params, T, Xs)
#      11     def _cumulative_hazard(self, params, T, Xs):
#      12 #         print(type(Xs["beta_"]))
#      13 #         print((Xs["beta_"]))
#      14 #         print(type(params["beta_"]))
#      15 #         print(params["beta_"])
# ---> 17         c = expit(np.dot(Xs["beta_"], params["beta_"]))
#      18         print(c)
#      21 #         print(Xs["lambda_"])
#      22 #         print(params["lambda_"])
#
# File /cita/modules/python/3.10.2/lib/python3.10/site-packages/autograd/tracer.py:48, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      46     return new_box(ans, trace, node)
#      47 else:
# ---> 48     return f_raw(*args, **kwargs)
#
# TypeError: ufunc 'expit' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
# # what's the effect on the survival curve if I vary "age"
# fig, ax = plt.subplots(figsize=(12, 6))

# cm.plot_covariate_groups(['age'], values=np.arange(20, 50, 5), cmap='coolwarm', ax=ax)
