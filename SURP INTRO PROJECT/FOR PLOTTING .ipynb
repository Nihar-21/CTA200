# %%
import numpy as np
from myfunctions import Simulation
from myfunctions import Plotting0#or Plotting

if __name__ == "__main__":
    #**********NEED TO CHANGE NE,NA VALUES based on what the simulation was run for!!!********
    Ne, Na,Nmu,Np = 4,4,2,2     # Np = number of test particles per (eb,ap)tuple 
    ab = 1
    ebs = np.linspace(0.,0.7,Ne)
    aps = ab*np.linspace(1.,5.,Na)
    mus = np.linspace(0.1,0.9,Nmu)

    stime = np.load('stime6.npy')
    print("we loaded {}".format(stime))
          
    
      
    #Plotting.Plotting0(ebs,aps,Na,stime,mus,Np,Ne,Nmu)
    for i, mu in enumerate(mus):
        for j in range(0,Np):
            Plotting0.Plotting0(ebs,aps,Na,stime[i,:,:,j],mu)     
    #Calling Plotting()function in Plotting.py (in folder/module myfunctions)
# Out:
# we loaded [[[[  634.66518254   634.66518254]
#    [62831.8530718  27925.26803191]
#    [  634.66518254   634.66518254]
#    [62831.8530718   5711.98664289]]
#
#   [[  634.66518254   634.66518254]
#    [62831.8530718   2538.66073017]
#    [  634.66518254   634.66518254]
#    [62831.8530718   7615.98219052]]
#
#   [[62831.8530718    634.66518254]
#    [62831.8530718  62831.8530718 ]
#    [ 1269.33036509   634.66518254]
#    [62831.8530718  62831.8530718 ]]
#
#   [[62831.8530718    634.66518254]
#    [62831.8530718  62831.8530718 ]
#    [ 1269.33036509   634.66518254]
#    [62831.8530718  62831.8530718 ]]]
#
#
#  [[[  634.66518254   634.66518254]
#    [62831.8530718   8885.31255561]
#    [  634.66518254   634.66518254]
#    [62831.8530718   5711.98664289]]
#
#   [[  634.66518254   634.66518254]
#    [62831.8530718   1903.99554763]
#    [  634.66518254   634.66518254]
#    [62831.8530718   1903.99554763]]
#
#   [[62831.8530718    634.66518254]
#    [62831.8530718  62831.8530718 ]
# ...
